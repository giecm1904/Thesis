# %%
import pathlib
import pandas as pd
import iso8601.iso8601
import datetime
import matplotlib.pyplot as plt
import collections
import tqdm
import itertools
import warnings
import numpy as np

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)


def round(t):
    t = datetime.datetime(t.year, t.month, t.day, t.hour, t.minute, t.second)
    return t


def makehash():
    return collections.defaultdict(makehash)



data_dir = pathlib.Path("Single-Region")
crh_dir = data_dir.joinpath("cr-h")
cro_dir = data_dir.joinpath("cr-o")
mcf_dir = data_dir.joinpath("mcf")
nep_dir = data_dir.joinpath("neptune")
vsvbp_dir = data_dir.joinpath("vsvbp")

run_dirs = [nep_dir, vsvbp_dir, mcf_dir, cro_dir, crh_dir]
#run_dirs = [vsvbp_dir, mcf_dir, cro_dir, crh_dir]

runs = list(range(3))

functions = [
    "compression",
    "dynamic-html",
    "graph-bfs",
    "graph-mst",
    "thumbnailer",
]

run = 4

result = makehash()

# %%
for run_dir, function, run_n in list(itertools.product(run_dirs, functions, runs)):
    req_df = pd.read_csv(run_dir.joinpath(f"{function}/{function}_{run_n}_proxy_metric.csv"))
    req_df['timestamp'] = req_df['timestamp'].map(lambda x: iso8601.parse_date(x))
    req_df['timestamp'] = req_df['timestamp'].map(round)
    min_time = min(req_df['timestamp'])
    max_time = max(req_df['timestamp'])
    req_df['timestamp'] = req_df['timestamp'] - min_time
    req_df = req_df.sort_values('timestamp')

    res_df = pd.read_csv(run_dir.joinpath(f"{function}/{function}_{run_n}_pod_log.csv"))
    res_df = res_df[res_df["container_name"].map(lambda x: function in x)]
    res_df['timestamp'] = res_df['timestamp'].map(lambda x: iso8601.parse_date(x))
    res_df['timestamp'] = res_df['timestamp'].map(round)
    res_df = res_df[res_df['timestamp'] < max_time]
    res_df = res_df[res_df['timestamp'] > min_time]
    res_df['timestamp'] = res_df['timestamp'] - min_time
    res_df = res_df.sort_values('timestamp')

    if run_dir is crh_dir:
        res_df = res_df[~res_df['pod_address'].isna()]
    if run_dir is cro_dir:
        res_df['cpu'] = res_df['cpu'] + np.random.normal(0, 0.5, len(res_df['cpu']))

    cpu = res_df.groupby("timestamp").sum()['cpu'].rolling(200, win_type="triang", min_periods=20).mean()
    rt = req_df.groupby("timestamp").mean()['latency'].rolling(200, win_type="triang", min_periods=20).mean()

    ms = req_df['timestamp'].dt.total_seconds()-res_df['timestamp'].dt.total_seconds()
    ms_f = [x for x in ms if not np.isnan(x)]
    ms_f = [0 if x < 0 else x for x in ms_f]

    result[run_dir][function]['cpu'][run_n] = cpu.to_numpy()
    result[run_dir][function]['rt'][run_n] = rt.to_numpy()
    result[run_dir][function]['delay'][run_n] = ms_f

    res_df = res_df.merge(pd.DataFrame({'timestamp':req_df['timestamp'].unique()}), on='timestamp', how="right").fillna(method='bfill').fillna(method='ffill')[:]

    p_req = pd.DataFrame({'timestamp': req_df['timestamp'],
                          'ms_timestamp': req_df['latency']})

    p_res = pd.DataFrame({'timestamp': res_df['timestamp'],
                          'ms_timestamp': res_df['response_time']})

    p_req_t = p_req.groupby("timestamp").mean()['ms_timestamp'].rolling(200, win_type="triang", min_periods=20).mean()
    p_req_t = p_req_t.dropna()
    p_res_t = p_res.groupby("timestamp").mean()['ms_timestamp'].rolling(200, win_type="triang", min_periods=20).mean()
    p_res_t = p_res_t.dropna()
    tiempo_final = p_req['ms_timestamp'].subtract(p_res['ms_timestamp'])
    tiempo_final = tiempo_final.dropna()

    net_delay = (p_req_t - p_res_t).clip(0).mean()
    print(f"{run_dir}, {function}, {run_n}, net delay = {net_delay}")
# Out:
# Single-Region\neptune, compression, 0, net delay = 40.97246422683767
# Single-Region\neptune, compression, 1, net delay = 70.35963711583177
# Single-Region\neptune, compression, 2, net delay = 62.13282535963576
# Single-Region\neptune, dynamic-html, 0, net delay = 55.49694309538946
# Single-Region\neptune, dynamic-html, 1, net delay = 18.930444035859445
# Single-Region\neptune, dynamic-html, 2, net delay = 28.82032030273988
# Single-Region\neptune, graph-bfs, 0, net delay = 0.04073637867885811
# Single-Region\neptune, graph-bfs, 1, net delay = 1.077947970231542
# Single-Region\neptune, graph-bfs, 2, net delay = 2.454766169524554
# Single-Region\neptune, graph-mst, 0, net delay = 2.0660387883443936
# Single-Region\neptune, graph-mst, 1, net delay = 7.001335189641398
# Single-Region\neptune, graph-mst, 2, net delay = 4.016663661660425
# Single-Region\neptune, thumbnailer, 0, net delay = 16.577819885170943
# Single-Region\neptune, thumbnailer, 1, net delay = 81.72959911609783
# Single-Region\neptune, thumbnailer, 2, net delay = 6.9179282238742195
# Single-Region\vsvbp, compression, 0, net delay = 48.00795683334898
# Single-Region\vsvbp, compression, 1, net delay = 77.2331689855021
# Single-Region\vsvbp, compression, 2, net delay = 48.05144594302273
# Single-Region\vsvbp, dynamic-html, 0, net delay = 105.77103256620546
# Single-Region\vsvbp, dynamic-html, 1, net delay = 102.17637732252196
# Single-Region\vsvbp, dynamic-html, 2, net delay = 97.64747156470567
# Single-Region\vsvbp, graph-bfs, 0, net delay = 1.8700620799047816
# Single-Region\vsvbp, graph-bfs, 1, net delay = 10.168534580089311
# Single-Region\vsvbp, graph-bfs, 2, net delay = 10.252675520874277
# Single-Region\vsvbp, graph-mst, 0, net delay = 7.716826707600136
# Single-Region\vsvbp, graph-mst, 1, net delay = 14.448897423919949
# Single-Region\vsvbp, graph-mst, 2, net delay = 16.324068202915697
# Single-Region\vsvbp, thumbnailer, 0, net delay = 13.851984064715447
# Single-Region\vsvbp, thumbnailer, 1, net delay = 19.494160262694752
# Single-Region\vsvbp, thumbnailer, 2, net delay = 52.14538623866838
# Single-Region\mcf, compression, 0, net delay = 53.95344924363595
# Single-Region\mcf, compression, 1, net delay = 45.866671597907974
# Single-Region\mcf, compression, 2, net delay = 34.37407037718181
# Single-Region\mcf, dynamic-html, 0, net delay = 53.36677516505603
# Single-Region\mcf, dynamic-html, 1, net delay = 29.767265724228547
# Single-Region\mcf, dynamic-html, 2, net delay = 31.178919722503004
# Single-Region\mcf, graph-bfs, 0, net delay = 0.5200859133113935
# Single-Region\mcf, graph-bfs, 1, net delay = 3.3996886070791543
# Single-Region\mcf, graph-bfs, 2, net delay = 11.16831116305859
# Single-Region\mcf, graph-mst, 0, net delay = 11.485805726372371
# Single-Region\mcf, graph-mst, 1, net delay = 4.366246294245091
# Single-Region\mcf, graph-mst, 2, net delay = 10.821742543768964
# Single-Region\mcf, thumbnailer, 0, net delay = 24.50092356795648
# Single-Region\mcf, thumbnailer, 1, net delay = 11.496488312113808
# Single-Region\mcf, thumbnailer, 2, net delay = 80.7214851321782
# Single-Region\cr-o, compression, 0, net delay = 26.406273389271917
# Single-Region\cr-o, compression, 1, net delay = 36.17699760506935
# Single-Region\cr-o, compression, 2, net delay = 103.59082998363444
# Single-Region\cr-o, dynamic-html, 0, net delay = 72.4352705043884
# Single-Region\cr-o, dynamic-html, 1, net delay = 44.695598760197974
# Single-Region\cr-o, dynamic-html, 2, net delay = 123.2361546373874
# Single-Region\cr-o, graph-bfs, 0, net delay = 0.9165213596904155
# Single-Region\cr-o, graph-bfs, 1, net delay = 3.1687554461945804
# Single-Region\cr-o, graph-bfs, 2, net delay = 12.919071747841645
# Single-Region\cr-o, graph-mst, 0, net delay = 5.250241236776438
# Single-Region\cr-o, graph-mst, 1, net delay = 16.231765516656374
# Single-Region\cr-o, graph-mst, 2, net delay = 45.476195034055245
# Single-Region\cr-o, thumbnailer, 0, net delay = 67.87154335315942
# Single-Region\cr-o, thumbnailer, 1, net delay = 48.730221869334486
# Single-Region\cr-o, thumbnailer, 2, net delay = 89.68733313951785
# Single-Region\cr-h, compression, 0, net delay = 52.91076210215081
# Single-Region\cr-h, compression, 1, net delay = 52.74812258315773
# Single-Region\cr-h, compression, 2, net delay = 64.01320153666008
# Single-Region\cr-h, dynamic-html, 0, net delay = 113.95525304472083
# Single-Region\cr-h, dynamic-html, 1, net delay = 11.022927279181705
# Single-Region\cr-h, dynamic-html, 2, net delay = 21.63372202185597
# Single-Region\cr-h, graph-bfs, 0, net delay = 0.898125156722273
# Single-Region\cr-h, graph-bfs, 1, net delay = 3.0623965062249727
# Single-Region\cr-h, graph-bfs, 2, net delay = 4.651104894529471
# Single-Region\cr-h, graph-mst, 0, net delay = 3.970231670245013
# Single-Region\cr-h, graph-mst, 1, net delay = 1.7333208958944464
# Single-Region\cr-h, graph-mst, 2, net delay = 35.149801584716876
# Single-Region\cr-h, thumbnailer, 0, net delay = 128.32061992154988
# Single-Region\cr-h, thumbnailer, 1, net delay = 45.34704815162251
# Single-Region\cr-h, thumbnailer, 2, net delay = 93.88996205312591
